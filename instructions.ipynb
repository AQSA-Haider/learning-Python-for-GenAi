# %% [markdown]
# ## Aqsa Haider
# ## Python Data Structures: Task-1,Task-2,Task-3 & Task-4

# %% [markdown]
# ## These Repository contains a clear implementation of fundamental python data structures (Lists,Tuples,Sets,Dictionary)

# %% [markdown]
# ## How to run the code

# %% [markdown]
# ## Navigate to the project folder in your terminal :

# %% [markdown]
# ## Bash
# https://github.com/AQSA-Haider/learning-Python-for-GenAi/tree/main

# %% [markdown]
# ## Launch Jupiter Notebook:

# %% [markdown]
# ## Bash
# jupiter notebook

# %% [markdown]
# ## Run the file:
# Assignment1.ipynb
# ## and press
# shift + enter
# ## to run the cells Sequentially
