# %% [markdown]
# ## My First Task

# %% [markdown]
# # Product Collection(List & Tuple)

# %%
product=["handbag","wallet","shoes","Jewelry","belt","sunglasses","watch","scarf","hat","gloves"]

# %%
print(product)
# Out:
# ['handbag', 'wallet', 'shoes', 'Jewelry', 'belt', 'sunglasses', 'watch', 'scarf', 'hat', 'gloves']

# %% [markdown]
# ##  Creating a Tuple Sample_product

# %%
sample_product=('handbag', 'wallet', 'shoes', 'Jewelry', 'belt', 'sunglasses', 'watch', 'scarf', 'hat', 'gloves',1000,500,2000,400,500,1000,500,400,200,300,"Bags" ,"acessories" ,"foot wear","fashion")

# %%
print(sample_product)
# Out:
# ('handbag', 'wallet', 'shoes', 'Jewelry', 'belt', 'sunglasses', 'watch', 'scarf', 'hat', 'gloves', 1000, 500, 2000, 400, 500, 1000, 500, 400, 200, 300, 'Bags', 'acessories', 'foot wear', 'fashion')

# %% [markdown]
# ## Print 2nd and last product

# %%
product[1]
# Out:
# 'wallet'

# %%
product[9]
# Out:
# 'gloves'

# %% [markdown]
# ## Append two new products

# %%
product.append("jacket")

# %%
product.append("pen")

# %% [markdown]
# ## Print the Updated list

# %%
print(product)
# Out:
# ['handbag', 'wallet', 'shoes', 'Jewelry', 'belt', 'sunglasses', 'watch', 'scarf', 'hat', 'gloves', 'jacket', 'pen']

# %% [markdown]
# ## Converting Tuple sample_product into list

# %%
new=[i for i in sample_product]

# %%
print(new)
# Out:
# ['handbag', 'wallet', 'shoes', 'Jewelry', 'belt', 'sunglasses', 'watch', 'scarf', 'hat', 'gloves', 1000, 500, 2000, 400, 500, 1000, 500, 400, 200, 300, 'Bags', 'acessories', 'foot wear', 'fashion']

# %%
print(len(new))
# Out:
# 24

# %% [markdown]
# ## updating the prices

# %%
print(new.index(1000))
print(new.index(300))
# Out:
# 10
# 19

# %%
new[10]=1500
new[11]=600
new[12]=2500
new[13]=500
new[14]=1000
new[15]=600
new[16]=600
new[17]=500
new[18]=300
new[19]=400

# %% [markdown]
# ## printing the new list

# %%
print(new)
# Out:
# ['handbag', 'wallet', 'shoes', 'Jewelry', 'belt', 'sunglasses', 'watch', 'scarf', 'hat', 'gloves', 1500, 600, 2500, 500, 1000, 600, 600, 500, 300, 400, 'Bags', 'acessories', 'foot wear', 'fashion']

# %% [markdown]
# ## converting back the List(new) into a tuple

# %%
new_tuple=tuple(new)
print(new_tuple)
# Out:
# ('handbag', 'wallet', 'shoes', 'Jewelry', 'belt', 'sunglasses', 'watch', 'scarf', 'hat', 'gloves', 1500, 600, 2500, 500, 1000, 600, 600, 500, 300, 400, 'Bags', 'acessories', 'foot wear', 'fashion')

# %% [markdown]
# ## Task completed !!!
