# %% [markdown]
# ## Second Task

# %% [markdown]
# ## Categories(Sets)

# %% [markdown]
# ## creating a set Categories

# %%
categories={"foot wear","fashion","staionary","watches"}

# %% [markdown]
# ## adding some more element to see if it accepts duplicades or not

# %%
categories.add("electronics")
categories.add("staionary")
categories.add("foot wear")
categories.add("fashion")
categories.add("acessories")

# %%
print(categories)
# Out:
# {'electronics', 'fashion', 'acessories', 'watches', 'staionary', 'foot wear'}

# %% [markdown]
# ## we can see it has ignored the duplicate and has added unique elements only.

# %% [markdown]
# ## Checking: whether a category exist in set

# %%
p=input("enter the category you want to search")
print(p in categories)
# Out:
# False

# %% [markdown]
# ## Calculating the no. of unique categories

# %%
n=len(categories)
print(n)
# Out:
# 6
