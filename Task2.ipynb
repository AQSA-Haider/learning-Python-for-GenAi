# %% [markdown]
# ## Second Task

# %% [markdown]
# ## Categories(Sets)

# %% [markdown]
# ## creating a set Categories

# %%
product=["handbag","wallet","shoes","Jewelry","belt","watch","harry potter"]

# %%
categories=["Bags" ,"acessories" ,"foot wear","jewels","fashion","watches","novels"]

# %% [markdown]
# ## converting categories list into a set

# %%
categories_set=set(categories)

# %% [markdown]
# ## adding some more element to see if it accepts duplicades or not

# %%
categories_set.add("electronics")
categories_set.add("stationary")
categories_set.add("foot wear")
categories_set.add("fashion")
categories_set.add("accessories")

# %%
print(categories_set)
# Out:
# {'electronics', 'stationary', 'Bags', 'jewels', 'accessories', 'fashion', 'foot wear', 'novels', 'acessories', 'watches'}

# %% [markdown]
# ## we can see it has ignored the duplicate and has added unique elements only.

# %% [markdown]
# ## Checking: whether a category exist in set

# %%
p=input("enter the category you want to search")
print(p in categories_set)
# Out:
# True

# %% [markdown]
# ## Calculating the no. of unique categories

# %%
n=len(categories)
print(n)
# Out:
# 7

# %% [markdown]
# ## task completed !!!
