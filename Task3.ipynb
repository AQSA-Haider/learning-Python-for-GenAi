# %% [markdown]
# ## Third Task

# %% [markdown]
# ## Product Pricing

# %% [markdown]
# ## Creating a Dictionary price_dict

# %%
price_dict={"fruits": 100, "vegetables": 200, "dairy": 300, "meat": 400,"beverages": 500,"snacks": 600, "grains": 700, "frozen": 800, "personal_care": 900, "household": 1000}
print("The categories available are:" )
print(price_dict)
# Out:
# The categories available are:
# {'fruits': 100, 'vegetables': 200, 'dairy': 300, 'meat': 400, 'beverages': 500, 'snacks': 600, 'grains': 700, 'frozen': 800, 'personal_care': 900, 'household': 1000}

# %% [markdown]
# ## Adding a new product
