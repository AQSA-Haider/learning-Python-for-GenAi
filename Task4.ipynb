# %% [markdown]
# ## Fourth Task

# %% [markdown]
# ## Combined Operation

# %% [markdown]
# ## firstly creating the product list and price_dict

# %%
product=["handbag","wallet","shoes","Jewelry","belt","sunglasses","watch","scarf","hat","gloves"]

# %%
rice_dict={"fruits": 100, "vegetables": 200, "dairy": 300, "meat": 400,"beverages": 500,"snacks": 600, "grains": 700, "frozen": 800, "personal_care": 900, "household": 1000}
